# %%
# %tensorflow_version 1.x

# %%
import tensorflow as tf
import numpy as np

# %%
x_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_data = np.array([[0],[1],[1],[0]], dtype=np.float32)

# %%
print('x_data : \n', x_data)
print('x_data shape : \n', np.shape(x_data))
print('y_data : \n', y_data)
print('y_data shape : \n', np.shape(y_data))
# Out:
# x_data :
#  [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# x_data shape :
#  (4, 2)
# y_data :
#  [[0.]
#  [1.]
#  [1.]
#  [0.]]
# y_data shape :
#  (4, 1)

# %%
# Placeholder
X = tf.placeholder(tf.float32, shape=[None, 2])
Y = tf.placeholder(tf.float32, shape=[None, 1])

# %%
# Weight, bias Variables
W1 = tf.Variable(tf.random_normal([2, 2]), name = 'weight')
b1 = tf.Variable(tf.random_normal([1]), name = 'bias')
# hidden layer
layer1 = tf.sigmoid(tf.matmul(X, W1) + b1)

W2 = tf.Variable(tf.random_normal([2, 1]), name = 'weight')
b2 = tf.Variable(tf.random_normal([1]), name = 'bias')
hypothesis = tf.sigmoid(tf.matmul(layer1, W2) + b2)

# %%
# cost function : binary cross entropy
cost = -tf.reduce_mean(Y * tf.log(hypothesis) + (1 - Y) * tf.log(1 - hypothesis))
# Gradient Descent Method
train = tf.train.GradientDescentOptimizer(learning_rate=0.2).minimize(cost)

# %%
predicted = tf.cast(hypothesis>0.5, dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

# %%
with tf.Session() as sess:
  sess.run(tf.global_variables_initializer())

  for step in range(3001):
    cost_val, _ = sess.run([cost, train], feed_dict={X:x_data, Y:y_data})
    if step % 100 == 0:
      print('step : ', step, ' cost : ', cost_val)

  h, p, a = sess.run([hypothesis, predicted, accuracy], feed_dict={X:x_data, Y:y_data})
  print("\nHypothesis: ", h, "\nPredicted: ", p, "\nAccuracy: ", a)
# Out:
# step :  0  cost :  1.9296603
# step :  100  cost :  0.69738954
# step :  200  cost :  0.6877055
# step :  300  cost :  0.6755223
# step :  400  cost :  0.6616401
# step :  500  cost :  0.6447846
# step :  600  cost :  0.6233382
# step :  700  cost :  0.59712017
# step :  800  cost :  0.567878
# step :  900  cost :  0.5381352
# step :  1000  cost :  0.509624
# step :  1100  cost :  0.48260757
# step :  1200  cost :  0.4555161
# step :  1300  cost :  0.4239114
# step :  1400  cost :  0.38150585
# step :  1500  cost :  0.33078095
# step :  1600  cost :  0.28132653
# step :  1700  cost :  0.2373057
# step :  1800  cost :  0.19993898
# step :  1900  cost :  0.16928661
# step :  2000  cost :  0.14458445
# step :  2100  cost :  0.12476811
# step :  2200  cost :  0.10881533
# step :  2300  cost :  0.09587154
# step :  2400  cost :  0.08526546
# step :  2500  cost :  0.07648307
# step :  2600  cost :  0.069134526
# step :  2700  cost :  0.062923834
# step :  2800  cost :  0.057625186
# step :  2900  cost :  0.05306507
# step :  3000  cost :  0.049108848
#
# Hypothesis:  [[0.0305325 ]
#  [0.9565138 ]
#  [0.9566782 ]
#  [0.07367599]]
# Predicted:  [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Accuracy:  1.0
